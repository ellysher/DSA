# %% [markdown]
# # LEETCODE QUESTIONS STACKS AND QUEUES
# # EASY
#
# 20 Valid Parentheses
#
# 232 Implement Queue using Stacks
#
# 225 Implement Stack using Queues
#
# 682 Baseball Game
#
# 844 Backspace String Compare
#
# 1047 Remove All Adjacent Duplicates In String
#
# 1021 Remove Outermost Parentheses
#
# 155 Min Stack
#
# 496 Next Greater Element I
#
# 2390 Removing Stars From a String

# %% [markdown]
# ## 20 Valid Parentheses
# ![image.png](attachment:image.png)

# %%
def isValid(s):
    stack = []
    closeToOpen = {")":"(","]":"[","}":"{"}
    for c in s:
        if c in closeToOpen:
            if stack and stack[-1]==closeToOpen[c]:
                stack.pop()
            else: 
                return False
        else:
            stack.append(c)

    return True if not stack else False


isValid(s = "()[]{})")
# Out:
# False

# %% [markdown]
# ## 232 Implement Queue using Stacks
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 225 Implement Stack using Queues

# %%
class MyQueue:
    def __init__(self):
        self.stack_in = []   # Stack for pushing elements
        self.stack_out = []  # Stack for popping elements

    def push(self, x: int) -> None:
        self.stack_in.append(x)

    def pop(self) -> int:
        self._move()
        return self.stack_out.pop()

    def peek(self) -> int:
        self._move()
        return self.stack_out[-1]

    def empty(self) -> bool:
        return not self.stack_in and not self.stack_out

    def _move(self) -> None:
        # Move elements from stack_in to stack_out only if stack_out is empty
        if not self.stack_out:
            while self.stack_in:
                self.stack_out.append(self.stack_in.pop())


# Create a queue object
queue = MyQueue()

# Push elements into the queue
queue.push(1)
queue.push(2)

# Peek the front element
print("Front element (Peek):", queue.peek())  # Expected output: 1

# Pop the front element
print("Popped element:", queue.pop())  # Expected output: 1

# Check if the queue is empty
print("Is queue empty?", queue.empty())  # Expected output: False

# Pop the remaining element
print("Popped element:", queue.pop())  # Expected output: 2

# Check if the queue is empty again
print("Is queue empty?", queue.empty())  # Expected output: True
# Out:
# Front element (Peek): 1
# Popped element: 1
# Is queue empty? False
# Popped element: 2
# Is queue empty? True

# %% [markdown]
# ## 682 Baseball Game
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def calPoints(operations):
    stack = []

    for op in operations:
        if op == "C":
            stack.pop()  # Remove the last valid score
        elif op == "D":
            stack.append(2 * stack[-1])  # Double the last valid score
        elif op == "+":
            stack.append(stack[-1] + stack[-2])  # Sum of the last two scores
        else:
            stack.append(int(op))  # Record the integer score

    return sum(stack)

# Example usage
operations = ["5", "2", "C", "D", "+"]
print("Total score:", calPoints(operations))
# Out:
# Total score: 30

# %% [markdown]
# ## 844 Backspace String Compare
# ![image-2.png](attachment:image-2.png)

# %%
def build_string(string):
    stack = []
    for char in string:
        if char == '#':
            if stack:
                stack.pop()  # Remove the last character
        else:
            stack.append(char)  # Add the current character
    return ''.join(stack)

def backspaceCompare(s, t):
    return build_string(s) == build_string(t)

# Example usage
s = "ab#c"
t = "ad#c"
print("Are the strings equal?", backspaceCompare(s, t))
# Out:
# Are the strings equal? True

# %% [markdown]
# ## 1047 Remove All Adjacent Duplicates In String

# %% [markdown]
# ## 1021 Remove Outermost Parentheses

# %% [markdown]
# ## 155 Min Stack

# %% [markdown]
# ## 496 Next Greater Element I

# %% [markdown]
# ## 2390 Removing Stars From a String

# %% [markdown]
# # MEDIUM
# 71 Simplify Path
#
# 150 Evaluate Reverse Polish Notation
#
# 227 Basic Calculator II
#
# 402 Remove K Digits
#
# 503 Next Greater Element II
#
# 739 Daily Temperatures
#
# 907 Sum of Subarray Minimums
#
# 1209 Remove All Adjacent Duplicates in String II
#
# 1475 Final Prices With a Special Discount in a Shop
#
# 1673 Find the Most Competitive Subsequence
#
# 856 Score of Parentheses
#
# 901 Online Stock Span
#
# 946 Validate Stack Sequences
#
# 1249 Minimum Remove to Make Valid Parentheses
#
# 1006 Clumsy Factorial
#
# 239 Sliding Window Maximum
#
# 739 Daily Temperatures
#
# 641 Design Circular Deque
#
# 622 Design Circular Queue
#
# 362 Design Hit Counter

# %% [markdown]
# ## 71 Simplify Path

# %% [markdown]
# ## 150 Evaluate Reverse Polish Notation

# %% [markdown]
# ## 227 Basic Calculator II

# %% [markdown]
# ## 402 Remove K Digits

# %% [markdown]
# ## 503 Next Greater Element II

# %% [markdown]
# ## 739 Daily Temperatures

# %% [markdown]
# ## 907 Sum of Subarray Minimums

# %% [markdown]
# ## 1209 Remove All Adjacent Duplicates in String II

# %% [markdown]
# ## 1475 Final Prices With a Special Discount in a Shop

# %% [markdown]
# ## 1673 Find the Most Competitive Subsequence

# %% [markdown]
# ## 856 Score of Parentheses

# %% [markdown]
# ## 901 Online Stock Span

# %% [markdown]
# ## 946 Validate Stack Sequences

# %% [markdown]
# ## 1249 Minimum Remove to Make Valid Parentheses

# %% [markdown]
# ## 1006 Clumsy Factorial

# %% [markdown]
# ## 239 Sliding Window Maximum

# %% [markdown]
# ## 739 Daily Temperatures

# %% [markdown]
# ## 641 Design Circular Deque

# %% [markdown]
# ## 622 Design Circular Queue

# %% [markdown]
# ## 362 Design Hit Counter

# %% [markdown]
# # ADVANCED
# 32 Longest Valid Parentheses
#
# 42 Trapping Rain Water
#
# 84 Largest Rectangle in Histogram
#
# 85 Maximal Rectangle
#
# 224 Basic Calculator
#
# 316 Remove Duplicate Letters
#
# 895 Maximum Frequency Stack
#
# 768 Max Chunks To Make Sorted II
#
# 1000 Minimum Cost to Merge Stones
#
# 1670 Design Front Middle Back Queue
#
# 2104 Sum of Subarray Ranges
#
# 1679 Max Number of K-Sum Pairs
#
# 2392 Build a Matrix With Conditions
#
# 1472 Design Browser History
#
# 2281 Sum of Total Strength of Wizards
#
# 2551 Put Marbles in Bags

# %% [markdown]
# ## 32 Longest Valid Parentheses

# %% [markdown]
# ## 42 Trapping Rain Water

# %% [markdown]
# ## 84 Largest Rectangle in Histogram

# %% [markdown]
# ## 85 Maximal Rectangle

# %% [markdown]
# ## 224 Basic Calculator

# %% [markdown]
# ## 316 Remove Duplicate Letters

# %% [markdown]
# ## 895 Maximum Frequency Stack

# %% [markdown]
# ## 768 Max Chunks To Make Sorted II

# %% [markdown]
# ## 1000 Minimum Cost to Merge Stones

# %% [markdown]
# ## 1670 Design Front Middle Back Queue

# %% [markdown]
# ## 2104 Sum of Subarray Ranges

# %% [markdown]
# ## 1679 Max Number of K-Sum Pairs

# %% [markdown]
# ## 2392 Build a Matrix With Conditions

# %% [markdown]
# ## 1472 Design Browser History

# %% [markdown]
# ## 2281 Sum of Total Strength of Wizards

# %% [markdown]
#  ## 2551 Put Marbles in Bags
