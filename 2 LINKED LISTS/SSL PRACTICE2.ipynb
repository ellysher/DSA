# %% [markdown]
# ## SINGLY LINKED LIST PRACTICE

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head= None


    def insert_begining(self, data):
        new_node = node(data)
        new_node.next=self.head
        self.head=new_node

    def insert_end(self,data):
        new_node= node(data)

        if self.head is None:
            self.head=new_node
            return

        curr = self.head
        while curr.next:
            curr= curr.next

        curr.next=new_node

    def insert_pos(self,pos,data):
        new_node= node(data)
        if pos == 1:
            self.insert_begining(data)
            return
        
        curr=self.head
        for _ in range(pos-1):
            curr=curr.next
        new_node.next = curr.next
        curr.next=new_node

    def delete_first_node(self):
        if self.head is None:
            return 
        
        self.head=self.head.next

    def delete_last_node(self):
        if self.head is None:
            return
        
        curr=self.head

        while curr.next.next:
            curr=curr.next

        curr.next = None


    def delete_node(self,key):
        if self.head is None:
            return
        
        if self.head.data ==key:
            self.head=self.head.next

            return
        
        curr=self.head

        while curr.next and curr.next.data != key:
            curr=curr.next

        if curr.next.next:
            curr.next=curr.next.next

        else: 
            curr.next = None






        



        

        



        





    

    def traverse(self):
        if self.head is None:
            return 'Empty List'
        
        curr=self.head
        while curr:
            print(curr.data, end= ' -> ')

            curr=curr.next

        print ('None')
        


ll= LinkedList()
ll.insert_begining(2)
ll.insert_begining(1)
ll.insert_end(4)
ll.insert_end(5)
ll.insert_pos(2,3)
ll.delete_node()
ll.traverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 122
#     120 ll.insert_end(5)
#     121 ll.insert_pos(2,3)
# --> 122 ll.delete_node(6)
#     123 ll.traverse()
#
# Cell In[4], line 73, in LinkedList.delete_node(self, key)
#      70 while curr.next and curr.next.data != key:
#      71     curr=curr.next
# ---> 73 if curr.next.next:
#      74     curr.next=curr.next.next
#      76 else:
#
# AttributeError: 'NoneType' object has no attribute 'next'
